# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# import data of height people living in Kazakhstan for exmaple
data = np.random.normal(160, 3, 1000)

# %%
sns.distplot(data)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Понятие дисперсии

# %% [markdown]
# $$
# D_x = \frac{\sum\limits_{i=1}^n (x - \bar{X}) ^ 2}{n}
# $$

# %% [markdown]
# $$
# sd = \sqrt{D_x}
# $$

# %%
def D_x_custom(data: np.array):
    return sum( (data - data.mean()) ** 2 ) / len(data)

def std_custom(data: np.array):
    return np.sqrt(D_x(data))

# %%
fig, ax = plt.subplots(1, 1)

# Построим график распределения
sns.distplot(data, kde = False, ax=ax)

# Найдем доверительные интервалы в 3 сигмы и раскрасим в разные цвета
std = std_custom(data)

start_point = data.mean()

ax.axvline(start_point, color='r', alpha=0.5)

# Right quantiles

for i in range(1, 4):
    ax.axvline(start_point + (std * i), color='g', alpha=0.4)
    ax.axvline(start_point - (std * i), color='g', alpha=0.4)

plt.show()
