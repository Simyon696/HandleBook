# %%
import pandas as pd

# %% [markdown]
# Численность населения 100 млн. человек.
#
# 24 миллиона - дети до 16 лет, а также
#
# люди, находящиеся в длительной изоляции (тюрьма)
# 30 миллионов человек выбыли из состава рабочей силы
#
# 4 миллиона 600 тысяч - безработные
#
# 1 миллион человек - работники, занятые не полный рабочий день и ищущие работу
#
# - Рассчитать велеичну рабочей силы
# - Рассчитать уровень безработицы

# %%
# Велечина рабочей силы
L = 100 - 24 - 30
U = 4.6
print(f"Велечина рабочей силы: {L}")
print(f"Уровень безработицы: {(U / L) * 100}%")
# Out:
# Велечина рабочей силы: 46
# Уровень безработицы: 10.0%

# %% [markdown]
# - Трансфертные платежи - 4 млрд.
# - Валовые внутренние инвестиции - 16.2
# - Косвенные налоги на бизнес - 7.0
# - Личные подоходные налоги - 2.6
# - Читсый экспорт - 1.1
# - Нераспределенная прибыль корпорации - 2.8
# - Амортизация - 7.9
# - Личные потребительские расходы - 77.2
# - Налоги на прибыль корпорации - 1.4
# - Взносы на социальное страхование - 0.2
# - Государственные закупки товаров и услуг - 8.5
#
# _**Рассчитать:**_ ВВП, Личный располагаемый доход
#
# ------------------
#
# По расходам (ВВП):
#
# ------------------
#
# - Личные потребительские расходы (77.2)
# - Валовые частные внутренние инвестиции (16.2)
# - Государственные закупки (8.5)
# - Чистый экспорт (1.1)
#
# ------------------
#
# **Итог:** 103
#
# По доходам (ВВП):
#
# ------------------
#
# - Амортизация (7.9)
# - Косвенные налоги на бизнес (1.4)
# - Нераспределенная прибыль корпорации (2.8)
# - Проценты (отсутствуют)
# - Рентные платежи (остуствуют)
#
# ------------------
#
# Посчитать по методу доходов - не возможно, так как не представленны все необходимые данные
#
#
# ЧНП
# ------------------
#
# ЧНП = ВВП - Амортизация (7.9)
#
#
# НД
# ------------------
# НД = Взносы на социальное страхование (0.2) - Косвенные налоги на бизнес (1.4) - Нераспределенная прибыль корпорации (2.8) + Трансфертные платежи (4) + Дивиденты (отсутсвуют)
#
#
# ЛД
# ------------------
#
# ЛД = НД - Личные подоходные налоги (2.6)

# %%
ЧНП = 103 - 7.9
НД = ЧНП - 0.2 - 1.4 - 2.8 + 4
ЛДР = НД - 2.6

# %%
НД
# Out:
# 94.69999999999999

# %%
ЧНП
# Out:
# 95.1

# %%
ЛДР
# Out:
# 92.1

# %% [markdown]
# 1. Человек, который надеется снова получить работу, относится к:
#
# - Безработный
# - Занятый
# - Не учитывается в составе рабочей силы
# - Рассматривается как неполностью занятый
# - Потерявший надежду быть занятым
#
# Относится к - **безработным**
#
# 2. Согласно закону оукена 2%-ое превышение фактического уровня безработицы над его естественным означает, что отстование фактического от реального сколько останется.

# %%
- 2.5 * 2
# Out:
# -5.0
